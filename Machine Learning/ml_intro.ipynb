# %%
import pandas as pd
import numpy as np
df1=pd.read_csv("C:\\Users\\chandini ch\\Downloads\\student_dataset_200_rows.csv")
#print(df1.head())
df=pd.DataFrame(df1)
print(df)
# Out:
#             name  age  study_hours  attendance  previous_score  final_score  \
# 0    Student_001   23          3.1          82              79           60
# 1    Student_002   20          1.7          68              95           65
# 2    Student_003   21          4.2          71              81           72
# 3    Student_004   23          2.5          60              55           50
# 4    Student_005   19          3.9          60              50           43
# ..           ...  ...          ...         ...             ...          ...
# 195  Student_196   22          3.8          84              76           69
# 196  Student_197   20          4.0          92              85           73
# 197  Student_198   18          6.2          97              51           66
# 198  Student_199   18          2.8          65              39           50
# 199  Student_200   21          2.3          91              63           62
#
#      Result
# 0         1
# 1         1
# 2         1
# ...
