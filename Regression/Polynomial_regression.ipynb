# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\chandini ch\\Downloads\\polynomial_regression_practice_dataset.csv")
print(df)
# Out:
#     Study_Hours  Marks
# 0             1      5
# 1             2      8
# 2             3     12
# 3             4     18
# 4             5     26
# 5             6     35
# 6             7     47
# 7             8     60
# 8             9     75
# 9            10     92
# 10           11    110
# 11           12    130
# 12           13    152
# 13           14    176
# 14           15    202
# 15           16    230
# 16           17    260
# 17           18    292
# 18           19    326
# 19           20    362
# 20           21    400
# 21           22    440
# 22           23    482
# 23           24    526
# 24           25    572
# 25           26    620
# 26           27    670
# 27           28    722
# 28           29    776
# 29           30    832

# %%
X=df[["Study_Hours"]]
y=df[["Marks"]]

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
best_score = 0
best_degree = 1
for i in range(1,6):
    poly = PolynomialFeatures(degree=i)
    x_poly = poly.fit_transform(X)
    lr = LinearRegression()
    lr.fit(x_poly,y)
    score = lr.score(x_poly,y)
    if score > best_score:
        best_score = score
        best_degree = degree
print("best_degree:", best_degree, "best_score:", best_score)
# Out:
# best_degree: 5 best_score: 0.999999188143999

# %%
poly = PolynomialFeatures(degree=best_degree)
lr.fit(x_poly,y)
print(lr.intercept_,lr.coef_)
# Out:
# [4.057542] [[ 0.00000000e+00  1.01380998e-01  8.65290534e-01 -2.69664575e-03
#    2.92356075e-04 -4.85861896e-06]]

# %%
pred_studyhrs = pd.DataFrame({"Study_Hours":[42]})
pred_marks = poly.transform(pred_studyhrs)
result = lr.predict(pred_marks)
print(result)
# Out:
# [[1609.64328753]]

# %%
import matplotlib.pyplot as plt
X_grid = np.linspace(X.min(), X.max(), 100).reshape(-1,1)
plt.scatter(X,y)
plt.plot(
    X_grid,
    lr.predict(poly.transform(X_grid))
)

plt.show()
# Out:
# d:\anaconda\envs\hand\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
