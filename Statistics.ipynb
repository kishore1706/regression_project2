# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
a=sns.get_dataset_names()
print(a)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
a=sns.load_dataset("flights")
print(a)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.histplot(data=a,x="passengers")
plt.show()

# %%
sns.displot(data=df,x="passengers",kde=True)
plt.show()

# %%
sns.ecdfplot(data=a,x="passengers")
# Out:
# <Axes: xlabel='passengers', ylabel='Proportion'>

# %%
sns.boxplot(data=a,x="passengers",y="month")
q1=np.percentile(a["passengers"],25)
print(q1)
q3=np.percentile(a["year"],75)
print(q3)
# Out:
# 180.0
# 1957.25

# %%
sns.violinplot(data=a,x="passengers")
# Out:
# <Axes: xlabel='passengers'>

# %%
sns.boxenplot(data=a,x="passengers",y="month")
# Out:
# <Axes: xlabel='passengers', ylabel='month'>

# %%
import pandas as pd
df=pd.DataFrame(a)
df.describe(include="all")
print(df)
# Out:
#                  0
# 0         anagrams
# 1         anscombe
# 2        attention
# 3   brain_networks
# 4      car_crashes
# 5         diamonds
# 6             dots
# 7         dowjones
# 8         exercise
# 9          flights
# 10            fmri
# 11          geyser
# 12            glue
# 13       healthexp
# 14            iris
# 15             mpg
# 16        penguins
# 17         planets
# 18          seaice
# 19           taxis
# 20            tips
# 21         titanic

# %%
sns.histplot(data=df,x="passengers",bins=10)
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %%
sns.scatterplot(data=df,x="month",y="passengers")
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.swarmplot(data=df, x="month", y="passengers")
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.swarmplot(data=df, x="passengers", y="month")
# Out:
# <Axes: xlabel='passengers', ylabel='month'>

# %%
sns.pairplot(data=df)

# %%
a=df["passengers"].corr(df["year"])
print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a=df["passengers"].corr(df["year"])
#       2 print(a)
#
# File d:\anaconda\envs\hand\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File d:\anaconda\envs\hand\Lib\site-packages\pandas\core\indexes\range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# ...

# %%
import scipy.stats as st
a=st.pearsonr(df["passengers"], df["year"])
print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 import scipy.stats as st
# ----> 2 a=st.pearsonr(df["passengers"], df["year"])
#       3 print(a)
#
# File d:\anaconda\envs\hand\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File d:\anaconda\envs\hand\Lib\site-packages\pandas\core\indexes\range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
# ...

# %%
a1=sns.load_dataset("iris")
a2=pd.DataFrame(a1)
#print(a2)
a2.drop('species',axis=1,inplace=True)
print(a2)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
import seaborn as sns
sns.heatmap(a2.corr(),annot=True)
plt.show()

# %%
sample_set=a2.sample(100)
print(sample_set)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 48            5.3          3.7           1.5          0.2
# 13            4.3          3.0           1.1          0.1
# 31            5.4          3.4           1.5          0.4
# 26            5.0          3.4           1.6          0.4
# 72            6.3          2.5           4.9          1.5
# ..            ...          ...           ...          ...
# 7             5.0          3.4           1.5          0.2
# 23            5.1          3.3           1.7          0.5
# 16            5.4          3.9           1.3          0.4
# 102           7.1          3.0           5.9          2.1
# 84            5.4          3.0           4.5          1.5
#
# [100 rows x 4 columns]

# %%
k=10
#systematicsampling
ss=a2.iloc[: :k]
print(ss)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 10            5.4          3.7           1.5          0.2
# 20            5.4          3.4           1.7          0.2
# 30            4.8          3.1           1.6          0.2
# 40            5.0          3.5           1.3          0.3
# 50            7.0          3.2           4.7          1.4
# 60            5.0          2.0           3.5          1.0
# 70            5.9          3.2           4.8          1.8
# 80            5.5          2.4           3.8          1.1
# 90            5.5          2.6           4.4          1.2
# 100           6.3          3.3           6.0          2.5
# 110           6.5          3.2           5.1          2.0
# 120           6.9          3.2           5.7          2.3
# 130           7.4          2.8           6.1          1.9
# 140           6.7          3.1           5.6          2.4
